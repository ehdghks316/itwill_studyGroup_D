# %% [markdown]
# <a href="https://colab.research.google.com/github/ehdghks316/itwill_studyGroup_D/blob/main/3_2%ED%8C%8C%EC%9D%B4%EC%8D%AC%EA%B8%B0%EC%B4%88.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
python
1990년 귀도 반 로성(Guido Van Rossum)개발한 인터프리터 언어
interpreter language(인터프리터 언어) : 한줄씩 소스코드를 해석해서 바로 실행해 결과를 확인할 수 있는 언어

특징
1. 문법이 쉽다.
2. 가독성 좋다.
3. 무료이다.
4. 이식성 좋다.
  - 쉽게 라이브러리를 추가 할 수 있다.
  - 운영체제에 종속되지 않는다.
5. 풍부한 라이브러리
  - numpy : 수학, 과학 모듈
  - pandas : 데이터 검색 모듈
  - matplotlib : 시각화 모듈
  - beautiple soup : 웹스크래핑 모듈
  - scikit-learn : 머신러닝 모듈
6. 동적타이밍
  - 런타임시에 type체크하는 동적타이밍을 지원
  - 메모리관리를 자동

# %%
'''
문자열
"문자열"
'문자열'
'''
print("오늘 하루도 행복하자")
print('오늘 하루도 행복하자!')

# 한 행 주석
'''
여러행 주석
'''
"""
여러행 주석
"""
# Out:
# 오늘 하루도 행복하자
# 오늘 하루도 행복하자!
# '\n여러행 주석\n'

# %%
# 사칙연산
1+2
2-1
2*3
7/2 # 나누기
7//2 # 몫 
7%2 # 나머지
2**3 # 제곱연산

type(2**3) # 타입확인

import math
math.pow(2,3)
type(math.pow(2,3))

# 연산자 우선 순위
1+2*3**3
(1+(2*(3**3)))
1.제곱연산
2. *,/,//,%
3. +,-

# %%
'''
# 변수
- 데이터를 저장할 수 있는 메모리 공간
- 첫 글자 영문, (한글), _(밑줄)
- 두 번째 글자부터는 영문, 한글, 숫자, _
- 대소문자 구분한다.
- 예약어는 사용할 수 없다.
'''
import keyword
keyword.kwlist

type(keyword.kwlist)

x = 10
x
type(x)
dir() # 메모리에 생성되어 있는 객체 확인
del x # 메모리에 생성되어 있는 객체 삭제
dir()

f=10.
type(f)

e=10.4e3 # 지수표현
e
10.4 * 10**3

# 연산자 축약
x = 1
x = x+1 -> x += 1
x = x-1 -> x -= 1
x = x*1 -> x *= 1
x = x/1 -> x /= 1
x = x//1 -> x //= 1
x = x%1 -> x %= 1

# %%
'''
[문제1] x,y 변수에 있는 값을 기준으로 수행한 결과 입니다. 
x 와 y 변수에 어떤 값이 있어야 하나요.
또한 결과값이 나오기 위해서 어떤 계산식을 만들어야 하는지 계산식을 만들어 보세요.

result_1 =  7
result_2 =  3
result_3 =  -3
result_4 =  10
result_5 =  0.4
result_6 =  0
result_7 =  2
result_8 =  32
result_9 =  7.0
result_10 =  -21
result_11 =  50
result_12 =  29
'''
x = 5
y = 2
result_1 = x+y
result_2 = x-y
result_3 = y-x
result_4 = x*y
result_5 = y/x
result_6 = y//x
result_7 = x//y
result_8 = y**x
result_9 = ((x*y)/y) + y # float(x+y)
result_10 = (x+y) * (y-x)
result_11 = (x*y) * x # (x**y)*y
result_12 = ((x*y) * x) + ((x+y) * (y-x)) # (x**2) + (y**2)

result_9
# Out:
# 7.0

# %%
# 논리연산자
x = 1
y = 2
x == y # 같다
x != y # 같지 않다
x > y # 크다
x >= y # 크거나 같다
x < y # 작다
x <= y # 작거나 같다

True and True
True and False
True or True
True or False
type(not True) # bool

# 문자열
str = "대한민국"
type(str)

str = """대한민국
짝짝짝"""
str

str = '대한민국 \n 짝짝짝'
str
print(str)

# escape code
# \n : 줄바꿈
str = '대한민국\n짝짝짝'
str
print(str) # \n를 적용하여 출력

# \t : tab key
str = '대한민국\t짝짝짝'
str # 있는 그대로 출력
print(str) # \t를 적용하여 출력

# \0 : null
str = '대한민국\0짝짝짝'
str
print(str)

# \' : 작은 따옴표가 문자로 표현
str = "대한민국'짝짝짝'"
str
print(str)
str = '대한민국\'짝짝짝\''
str
print(str)

# \" : 큰 따옴교가 문자료 표현
str = "대한민국\"짝짝짝\""
str
print(str)

# 문자 복제
x = "홍길동"
y = "파이썬 개발자"
x + ' ' + y # 문자 + 문자 = 문자, 연결연산자
(x + ' ' + y) * 100 # 문자((x + ' ' + y))를 100번 복제

print("*"*100) # * 을 100개 복제

# %%
x = "홍길동"
y = "발라드"

# {} 위치
print("안녕하세요,{}입니다. 즐겨듣는 음악은 {}입니다.".format(x,y))
z = "안녕하세요,{}입니다. 즐겨듣는 음악은 {}입니다.".format(x,y)
z
"안녕하세요,"+x+"입니다. 즐겨듣는 음악은 " +y+ "입니다."

# %s 문자의 위치
z = "안녕하세요,%s입니다. 즐겨듣는 음악은 %s입니다."%('제임스','락')
z

x = "100"
"문자" + x + "문자" # x가 숫자이면 오류/ "100"은 문자로 취급

#문자 사칙연산(+) 문자 = 연결연산자
#문자 사칙연산(+) 숫자 = 오류

# divmod : 몫과 나머지를 동시에 출력해주는 함수
x = 996
y = 8
quotient = x//y # 몫
remainder = x%y # 나머지

print("{}를 {}로 나누면 몫은 {}이고 나머지는 {}입니다.".format(x,y,quotient,remainder))
print("%s를 %s로 나누면 몫은 %s이고 나머지는 %s입니다."%(x,y,quotient,remainder))
print("%d를 %d로 나누면 몫은 %d이고 나머지는 %d입니다."%(x,y,quotient,remainder))

type(divmod(x,y)) #tuple
divmod(x,y) # 몫과 나머지를 동시에 출력해주는 함수

q, r = divmod(x,y)
q
r
q,r # 둘 다 출력
print("%d를 %d로 나누면 몫은 %d이고 나머지는 %d입니다."%(x,y,q,r))

print("원주율은 %s"%3.141592)
print("원주율은 {}".format(3.141592))
print("원주율은 %d"%3.141592) # %d는 정수로 수행됨
print("원주율은 %f"%3.141592) # %f는 실수형으로 수행

# %d
print('%d'%100)
print('%5d'%100) # 5자리까지 출력, 빈자리는 공백
print('%05d'%100) # 5자리까지 출력, 빈자리는 0
print('{:5}'.format(100)) # 5자리까지 출력, 빈자리는 공백
print('{:05}'.format(100)) # 5자리까지 출력, 빈자리는 공백

# %f
print('%.4f'%(3.141592)) # 소수점 4째자리까지 출력(5째에서 반올림)
print('{:.5}'.format(3.141592)) #소수점 4째자리까지 출력(5째에서 반올림)
print('%08.3f'%(3.141592)) # 8자리 출력(점 포함, 소숫점3째자리까지 포함, 빈공간은 0) -> 0003.142
print('%8.3f'%(3.141592)) # 8자리 출력(점 포함, 소숫점3째자리까지 포함, 빈공간은 공백) -> 0003.142

# %%
#len : 문자의 길이
x = "행복한 하루를 보내자"
len(x)

# 인덱싱, 슬라이싱
x[0]
x[1]
x[-1] # 뒤에서부터
x[-2]

x[:] # 처음부터 끝까지
x[0:3] # [시작인덱스:종료인덱스+1]
x[4:]
x[4:6]
x[4:-5]

x = '0123456789'
x[:]
x[::1]
x[::2] # 첫 인덱스부터 +2(인덱스)
x[::3] # 첫 인덱스부터 +3(인덱스)
x[0:7:2] # [시작인덱스:종료인덱스:증가분]
x[1:9:2]
x[5::2] # 5번인덱스부터:끝까지:2씩증가
x[::-1] # 역순으로 출력

x = '파리썬'
# x[1] = '이' -> 인덱스 번호를 이용해서 문자를 수정할 수 없다.
x[0] + '이' + x[2]


## 문자함수

# replace : 문자를 치환하는 함수
x = '파리썬 파리썬'
x = x.replace('리','이') 
x

# startswith : 원본 문자열이 입력한 문자로 시작되는지 판단하는 함수
x = 'hello world'
x[0] == 'h'
x.startswith('h')
x[0] == 'H' # 대소문자 구분
x.startswith('H') # 대소문자 구분

# endswith : 원본 문자열이 입력한 문자로 끝나는지 판단하는 함수
x = 'hello world'
x[len(x)-1] == 'd'
x.endswith('d')
x[-2:] == 'ld'
x.endswith('ld')

# find,index : 원본 문자열에서 입력한 문자가 존재하는 위치를 찾는 함수
x = 'hello world'
x.find('w') # 6번째 인덱스
x[x.find('w')]
x.find('W') # 찾는 문자가 없으면 -1로 리턴
x.find('world')
x.find('o') # 제일 먼저 나오는 o의 위치를 리턴
x.find('o',0) # x.find('o',시작인덱스)
x.find('o',5) # 5번째 인덱스부터 o의 위치를 찾음
x.find('o',8) # 찾는 문자열이 없으면 -1로 리턴

x.index('o')
x.index('o',5)
#x.index('o',8) -> 찾는 문자열이 없으면 오류 발생

# count : 입력한 문자열이 몇 번 나오는지를 리턴하는 함수
x.count('o')
x.count('l')

# 변수에 문자열이 있으면 True 없으면 False를 리턴해야 한다면
x.find('o') >= 0
x.find('O') >= 0
'o' in x
'O' in x

x = 'hello wolrd'
# upper : 대문자로 리턴하는 함수
x.upper()

# lower : 소문자로 리턴하는 함수
x.lower()

# capitalize : 첫글자 대문자 나머지는 소문자로 리턴하는 함수
x.capitalize()

# title : 공백문자를 기준으로 단어 별로 첫글자 대문자 나머지는 소문자로 리턴하는 함수
x.title()

# swapcase : 대문자는 소문자로 소문자는 대문자로 변환하는 함수
x = 'Hello World'
x.swapcase()

# 자리수를 고정시킨 후 문자열을 중앙, 왼쪽, 오른쪽에 배치하는 함수
x.center(20)
x.ljust(20)
x.rjust(20)

x = '     hello     '
len(x)
# 양쪽 공백, 오른쪽 공백, 왼쪽 공백을 제거하는 함수
x.strip()
x.rstrip()
x.lstrip()
x.strip(' ')
x.rstrip(' ')
x.lstrip(' ')

# 접두, 접미부분에 문자열 제거
x = 'whellow'
x.strip('w')
x.lstrip('w')
x.rstrip('w')

x = 'hello'
y = 'hello2022'
z = '안녕하세요'
# 문자열안에 알파벳, 한글로 이루어져있는지 확인하는 함수
x.isalpha()
y.isalpha() # false
z.isalpha()

# 문자열안에 알파벳, 한글, 숫자로 이루어져있는지 확인하는 함수
x.isalnum()
y.isalnum()
z.isalnum()

# 문자열안에 숫자로 이루어져있는지 확인하는 함수
x.isnumeric()
y.isnumeric()
z.isnumeric()

d = '2022'
d.isalpha()
d.isalnum()
d.isnumeric()

# 분할하는 함수
x = 'hello,world'
x.split(',') # ,로 분할하여 리스트로 출력

x = 'hello world'
x.split(' ')

x = 'abc'
x[0] + ',' + x[1] + ',' + x[2]
z = ','.join(x) # 각 글자(공백 등도 포함) 사이사이에 ,를 넣기
z.split(',') # 분할

z = ' '.join(x)
z.split(' ')
# Out:
# ['a', 'b', 'c']

# %%
x = "a b c d e f g"
#[문제2] x 변수의 문자의 갯수를 구하세요.
len(x)
print(len(x))
#[문제3] x 변수의 공백문자의 갯수를 구하세요.
x.count(' ')
print(x.count(' '))
#[문제4] x 변수의 공백문자를 제외한 갯수를 구하세요.
print(len(x.replace(' ','')))
len(x[::2])
#[문제5] x 변수에 있는 공백문자를 제거한 후 y변수에 입력해주세요
y = x.replace(' ','')

#[문제6] y 변수에 있는 문자를 분리한 후 z변수에 입력해주세요.
z = ' '.join(y).split(' ')
print(z)

url = 'http://www.python.org'
#[문제7] http:// 제거한 후 url 변수에 입력해 주세요.
url.replace('http://','')
url.lstrip('http://')
print(url)

#[문제8] url변수에 있는 문자 데이터에 '.'을 기준으로 분리하세요.
url = url.split('.')

#[문제9] url변수에 있는 문자데이터를 www.python.org 모양으로 만드세요.
url[0] + '.' + url[1] + '.' + url[2]
url = '.'.join(url)

#[문제10] url변수에 있는 문자데이터를 대문자로 변환하세요.
url.upper()

#[문제11] url변수에 있는 문자데이터를 소문자로 변환하세요.
url.lower()

# %%
# 파이썬(python) 자료형
'''
1. list
- 데이터의 목록을 다루는 자료형
- 서로다른 데이터 타입을 가질 수 있는 자료형
- 중첩할 수 있다.
- []
- list()
'''

x1 = []
type(x1)

x2 = list()
type(x2)

x = [10,20,30]
x
type(x)
len(x)
x[0]
x[1]
x[2]
x[-1]
x[-2]
x[-3]

x[0:2]
x[1:]
x[:-1]

# 리스트 값 수정
x[0] = 100
x[1:3] = [200,300]
x

# 리스트에 값을 추가
x.append(400)
x

x1 =[600,700]
x.extend(x1)

# 인덱스를 이용해서 특정한 위치에 값을 입력하는 함수
x[4]
x.insert(4,500) # 4번째 인덱스의 값에 500을 입력 , 원래있던 값들은 뒤로 밀려남
x[4]

x2 = [800,900,1000]

# 서로 다른 리스트를 결합하는 방법
z = x + x2 # 변수에다 저장하지 않으면 미리보기
z

z[:-1]
del z[-1]
#z.rstrip[1000] # 리스트에서 사용불가

z.pop() # 끝에 있는 값 빼내기
z

# 특정한 인덱스에 있는 값을 제거하는 방법
del z[2] # 2번째 인덱스 값 제거
z

z.pop(2) # 2번째 인덱스 값 제거
z

drink = ['콜라','사이다','콜라','환타','사이다','콜라']
# 리스트 변수에 있는 값을 출력하는 방법
len(drink)
drink.count('콜라')
# drink.find('콜라') 리스트 변수에서는 find함수를 사용할 수 없다.
drink.index('콜라')
drink.index('콜라',1)
drink.index('콜라',3)
#drink.index('콜라',6)

# 리스트 변수에 있는 값을 제거하는 방법
drink = ['콜라','사이다','콜라','환타','사이다','콜라']
del drink[drink.index('콜라')]
del drink[drink.index('콜라')]
del drink[drink.index('콜라')]
drink

drink = ['콜라','사이다','콜라','환타','사이다','콜라']
drink.pop(drink.index('콜라'))
drink.pop(drink.index('콜라',1))
drink.pop(drink.index('콜라',3))
drink

drink = ['콜라','사이다','콜라','환타','사이다','콜라']
drink.remove('콜라')
drink.remove('콜라')
drink.remove('콜라')
drink

# 중첩리스트
x = [1,2,3,['a','b','c'],4,5,6]
x
type(x)
type(x[0])
type(x[3])
x[3][0]
x[3][0:3]
x[3][0:2]
type(x[3][0])

x[3].append('d')
x[3].pop()
x[3][0] = x[3][0].upper()
x[3][1] = x[3][1].upper()
x

# 리스트 변수값을 지우는 함수
x.clear() # 모두지우기
x

x.append(1)
x.append(2)
x
dir()
id(x) # x라는 변수가 있는 메모리 주소

x.clear()
id(x)

del x # 변수 삭제(메모리에서 제거)
#id(x)

# 리스트 변수안에 값을 기준으로 오름차순 정렬(바로 적용)
x = [1,5,3,4,2]
x.sort()
x

# 리스트 변수안에 값을 기준으로 내림차순 정렬(바로 적용)
x = [1,5,3,4,2]
x.sort(reverse = True)
x

# 리스트 변수안에 값을 기준으로 오름차순 정렬(미리보기)
x = [1,5,3,4,2]
sorted(x)
x

# 리스트 변수안에 값을 기준으로 내림차순 정렬(미리보기)
x = [1,5,3,4,2]
sorted(x,reverse = True)
x

# 리스트 변수값을 역순으로 출력(미리보기)
x = [1,5,3,4,2]
x[::-1]
x

# 리스트 변수값을 역순으로 출력(바로 적용)
x = [1,5,3,4,2]
x.reverse()
x
# Out:
# [2, 4, 3, 5, 1]
