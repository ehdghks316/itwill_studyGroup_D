# %% [markdown]
# <a href="https://colab.research.google.com/github/ehdghks316/itwill_studyGroup_D/blob/main/4_14%ED%8C%8C%EC%9D%B4%EC%8D%AC(numpy%ED%95%A8%EC%88%98%2C%EB%B0%B0%EC%97%B4%2C_KNN%EC%95%8C%EA%B3%A0%EB%A6%AC%EC%A6%98).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
20220414

■ numpy
- 다차원배열을 지원하는 라이브러리
- 단일데이터 타입의 값을 갖는다.

import numpy as np
from pandas import DataFrame,Series
import pandas as pd

x = np.array([1,2,3])
x
type(x)
x.dtype
x.shape # 차원정보
x.ndim # 몇 차원인지

x1 = np.array([[1,2,3],[4,5,6]])
x1
type(x1)
x1.dtype
x1.shape
x1.ndim

x = np.array([1,2,'3'])
x
type(x)
x.dtype
x.shape
x.ndim

lst = [[1,2,3],[4,5,6],[7,8,9]]
lst
type(lst)
x2 = np.array(lst)
type(x2)
x2.dtype
x2.shape
x2.ndim

pd.DataFrame(x2)
pd.Series(x2) # 단일행만 사용가능

pd.Series(x2[0])

x2[0]
x2[1]
x2[2]
x2[:,0]
x2[:,1]
x2[:,2]
x2[0:2,0]
x2[0:2,0:1]

x2[0,0]
x2[2,2]
x2[1,2]
x2[[0,2,1],[0,2,2]]

b = np.array([[False,True,False],[True, False, True],[False, True, False]])

b.dtype
b.shape
b.ndim
x2[b] # true인 것만 추출
x2[x2%2==0] # 짝수인 것만 추출

# 배열을 모두 0으로 채우는 함수
np.zeros((3,3))

# 배열을 모두 1로 채우는 함수
np.ones((3,3))

# 배열의 사용자가 지정한 값으로 채우는 함수
np.full((5,5),3)

# 대각선을 1로 채우고 나머지는 0으로 채우는 함수(대각행렬)
np.eye(3)


list(range(20))

x = np.array(range(20))
x
x.shape
x.ndim
x = x.reshape((4,5))
x.shape
x.reshape((5,4))
x = x.reshape((20,)) # 1차원
x.shape
x.ndim 

x = np.array([1,2,3])
y = np.array([4,5,6])

#더하기
x + y # 인덱스끼리 더함
x[0] + y[0]
x[1] + y[1]
x[2] + y[2]
np.add(x,y)

# 빼기
x-y
np.subtract(x,y)

# 곱하기
x*y 
np.multiply(x,y)

# 나누기
x/y
np.divide(x,y)

x = np.array([[1,2],[3,4]])
y = np.array([[5,6],[7,8]])
 
x[0][0]
y[0][0]
x+y
np.add(x,y)

x-y
np.subtract(x,y)

x*y
np.multiply(x,y) # 인덱스끼리 곱 (행렬의 곱x)

x/y
np.divide(x,y)

# 행렬의 곱
np.dot(x,y)

x.shape
y.shape

np.sum(x) # 전체합
np.sum(x,axis=0) # 열기준의 합
np.sum(x,axis=1) # 행기준의 합

np.mean(x) # 전체 평균
np.mean(x,axis=0) # 열기준의 평균
np.mean(x,axis=1) # 행기준의 평균

np.var(x) # 전체 분산
np.var(x,axis=0) # 열기준의 분산
np.var(x,axis=1) # 행기준의 분산

np.std(x) # 전체 표준편차
np.std(x,axis=0) # 열기준의 표준편차
np.std(x,axis=1) # 행기준의 표준편차

np.max(x) # 전체 최대값
np.max(x,axis=0) # 열기준의 최대값
np.max(x,axis=1) # 행기준의 최대값

np.min(x) # 최소값
np.min(x,axis=0) # 열기준의 최소값
np.min(x,axis=1) # 행기준의 최소값

np.median(x) # 중앙값
np.median(x,axis=0) # 열기준의 중앙값
np.median(x,axis=1) # 행기준의 중앙값

x = x.reshape((4,))
np.max(x)

np.argmax(x) # 최대값의 인덱스
np.argmin(x) # 최소값의 인덱스

x = np.array([[1,2],[3,4],[0,15]])
x
np.argmax(x) # 1차원으로 펼쳤을 때의 인덱스 번호 
np.argmax(x.reshape((6,)))
np.argmax(x,axis=0) # 열기준
np.argmax(x,axis=1) # 행기준

np.argmin(x) # 1차원으로 펼쳤을 때의 인덱스 번호 
np.argmin(x.reshape((6,)))
np.argmin(x,axis=0)
np.argmin(x,axis=1)

# 누적합
np.cumsum(x)
np.cumsum(x.reshape((6,))) 
np.cumsum(x,axis=0)
np.cumsum(x,axis=1)

# 누적곱
np.cumprod(x) 
np.cumprod(x.reshape((6,)))
np.cumprod(x,axis=0)
np.cumprod(x,axis=1)

# 전체곱
np.prod(x)
np.prod(x.reshape((6,)))
np.prod(x,axis=0)
np.prod(x,axis=1)

# 연속적인 숫자 표현
list(range(5))
np.arange(5)

# reshape 옵션 order='C',order='F'
y = np.arange(10)
y.reshape((5,2)) # 행우선으로 값이 채워진다.
y.reshape((5,2),order='C') # 행우선으로 값이 채워진다.(기본값)
y.reshape((5,2),order='F') # 열우선으로 값이 채워진다.

y = np.arange(10).reshape((5,2),order='F')
y

y.reshape((10,))
y.reshape((10,),order='C') # 차원바꿀 때 행우선(기본값)
y.flatten('C') # reshape할 필요없이 1차원으로 뿌려주기

y.reshape((10,),order='F') # 열우선으로 1차원으로 바꾸기
y.flatten('F')

y.ravel()
y.ravel('C')
y.ravel('F')
 # flatten과 ravel차이 : flatten은 numpy배열에 대해서만 호출가능, ravel은 모든 개체 가능
x = np.array([[1,2,3],[4,5,6]])
y = np.array([[7,8,9],[10,11,12]])

np.concatenate([x,y]) # concatenate함수 사용할 때 리스트형식 사용(배열 사용시?) [x,y]
np.concatenate([x,y],axis=0)
np.vstack([x,y]) # 리스트로 행 합치기

np.concatenate([x,y],axis=1)
np.hstack([x,y]) # 열끼리 붙이기

x = np.array([[1,2],[3,4]])
x+4 # broadcast
x + np.full((2,2),4)
x.shape

z = np.array([10,20])
z.shape
# z = np.array([[10,20],[10,20]]) 
x+z # broadcast로 shape형태를 맞춰서 들어감

x = np.arange(3)
x.repeat(2) # 각 값을 2개씩 
x.repeat([2,3,4]) # 각 값을 숫자에 맞게 반복

x = np.array([[1,2],[3,4]])
x.repeat(2)
x.repeat(2,axis=0)
x.repeat(2,axis=1)
np.tile(x,2) #행순서랑 같이 복제

# unique값만 추출
np.unique([1,2,3,1,2,3,4,2])
x = np.array(['a','a','b','b'])
np.unique(x)
word, cnt = np.unique(x,return_counts=True) # unique값과 빈도수까지 출력
word
cnt

y = np.array([[1,0,0],[1,0,0],[1,0,0]])
np.unique(y)
np.unique(y,axis=0) # 열
np.unique(y,axis=1) # 행

x = np.arange(0,20,2)
y = np.arange(0,30,3)
x > y
x <= y

# 큰 값 찾기
np.maximum(x,y) # x변수의 값들과 y값들의 같은 인덱스를 비교해서 큰 값 찾기
# 작은 값 찾기
np.minimum(x,y) # x변수의 값들과 y값들의 같은 인덱스를 비교해서 작은 값 찾기

# 합집합
np.union1d(x,y)
# 교집합
np.intersect1d(x,y)
# 차집합
np.setdiff1d(x,y)

x = np.array([5,6,1,2,4,3,9])
np.sort(x) # 오름차순 정렬(미리보기)
np.sort(x)[::-1] # 내림차순 정렬(미리보기)

y = np.array([[3,1,7],[2,8,4],[5,4,6]])
np.sort(y)
np.sort(y,axis=1) # 행기준(기본값)
np.sort(y,axis=0) # 열기준
np.sort(y,axis=1)[::-1] # 행기준 내림차순
np.sort(y,axis=0)[::-1] # 열기준 내림차순

x = np.array([5,6,1,2,4,3,9])
np.sort(x)

x.argsort() # 오름차순 정렬한 인덱스 값을 리턴
x.argsort()[::-1] # 내림차순 정렬한 인덱스 값을 리턴
x[x.argsort()]
x[x.argsort()[::-1]]


★ kNN(k-Nearest Neighbors), k번째 가장 가까운(최근접) 이웃
- 사회적인 관점
    비슷한 사람끼리 모이는 성질
    비슷한 취향의 사람끼리 모여서 동호회를 만든다. 
    비슷한 부류의 계층 사람끼리 친분을 맺기도 한다.
    
- 공간적인 관점
    가구점
    맛집
    중고차 매장들(수원)
    왕갈비(수원)
    한약방

- 거리계산 알고리즘

- 유클리드 거리(Euclidean distance)

두점사이의 거리
1. 수직선

----|-----|------
    a     b
    큰값 - 작은값
    |b-a|
    
2. 평면
- 피타고라스 정리

p(x1,y1)
q(x2,y2)

math.sqrt((x1-x2)**2 + (y1-y2)**2)
np.sqrt((x1-x2)**2 + (y1-y2)**2)

[문제196] 거리계산을 한 후 가장 가까운 3개만 추출해주세요.
pointlst = [(1,1),(1,0),(2,0),(0,1),(2,2),(1,5),(2,3)]
point = [2,1]

pointlst[0][0]
pointlst[0][1]
point[0]
point[1]

result = []
for i in range(len(pointlst)):
    result.append(np.sqrt((pointlst[i][0] - point[0])**2 + (pointlst[i][1] - point[1])**2))
np.array(pointlst)[np.argsort(result)][:3] # pointlst가 lst형식이므로 array로 형식을 맞춰줘야함

# (np.argsort(result) <= 2).tolist() # 리스트 형식으로 변경

# 강사님 답
np.sqrt((point[0] - pointlst[0][0])**2 + (point[1] - pointlst[0][1])**2)
np.sqrt((point[0] - pointlst[1][0])**2 + (point[1] - pointlst[1][1])**2)

result = []
for i in pointlst:
    result.append(np.sqrt((point[0] - i[0])**2 + (point[1] - i[1])**2))

result
[1.0, 1.4142135623730951, 1.0, 2.0, 1.0, 4.123105625617661, 2.0]
sorted(result)
[1.0, 1.0, 1.0, 1.4142135623730951, 2.0, 2.0, 4.123105625617661]

for idx, value in enumerate(result):
    print(idx,value)

[i for i in sorted(enumerate(result),key=lambda x : x[1])][:3] # 인덱스랑 값 같이 출력
k = [i[0] for i in sorted(enumerate(result),key=lambda x : x[1])][:3] # 인덱스만 뽑겠다
for i in k:
    print(pointlst[i])
#import operator
#sorted(enumerate(result),key=operator.itemgetter(1))

x = np.array(result)
np.argsort(x)
np.argsort(result)[::-1]

point_array = np.array(pointlst)
point_array[np.argsort(x)][:3]

for i in np.argsort(result)[:3]:
    print(pointlst[i])
    
'''    
for i,j in pointlst:
    print(np.sqrt((point[0] - i)**2 + (point[1] - j)**2))
'''    

# 강사님 답2 array로 바꾸고 작업하기 (효율이 훨씬 좋음)
pointlst = [(1,1),(1,0),(2,0),(0,1),(2,2),(1,5),(2,3)]
point = [2,1]

point1 = np.array(pointlst)
point2 = np.array(point)

pow(point1 - point2,2) # 제곱 함수 pow(값, 제곱)
np.sqrt(np.sum(pow(point1 - point2,2),axis=1))
dist = np.sqrt(np.sum(np.square(point1 - point2),axis=1)) #numpy에서 제공하는 제곱합수 square

    #인덱스값으로 추출1
for i in np.argsort(dist)[:3]:
    print(pointlst[i])
    
    #인덱스값으로 추출2
for i in np.argsort(dist)[:3]:
    print(point1[i])
    
    #인덱스값으로 추출3
np.take(point1,np.argsort(dist)[:3],axis=0)

재료        단맛        아삭한맛        종류          거리
----------------------------------------------------------
포도         8            5            과일       np.sqrt((6-8)**2+(4-5)**2) = 2.2
콩           3            7            채소       np.sqrt((6-3)**2+(4-7)**2) = 4.2
견과         3            6           단백질      np.sqrt((6-3)**2+(4-6)**2) = 3.6
오렌지       7            3            과일       np.sqrt((6-7)**2+(4-3)**2) = 1.4

토마토 단맛 6, 아삭한 맛 4
k = 1
오렌지와 토마토 거리는 1.4로 가까이 이웃하여 과일로 분류
k = 3
오렌지,포도,견과 세가지 사이에서 다수결로 정한다.
종류 과일, 과일, 단백질 중에 다수결로 과일로 분류한다.


[문제197] food.csv읽어 들인후 토마토 단맛 6, 아삭한맛 4를 이용해서 거리계산한 값을 dist 컬럼에 입력해주세요.
dist 컬럼의 값을 오름차순으로 rank컬럼을 추가해주세요
food = pd.read_csv('c:/data/food.csv')
food

feature : 변수, 예측, 분류를 하기위해서 사용되는 입력변수
독립변수, 설명변수, 입력변수 : 종속변수에 영향을 주는 변수
종속변수, 결과변수 : 영향을 받는 변수

#tomato = (6,4) # (sweetness,crunchiness)

food['dist'] = np.sqrt((food['sweetness'] -6)**2 + (food['crunchiness'] - 4)**2 )
food['rank'] = food['dist'].rank(ascending=True,method='dense').astype(int)
y = food.loc[food['rank'] <= 3, 'class'].value_counts() == food.loc[food['rank'] <= 3, 'class'].value_counts().max()
x = food.loc[food['rank'] <= 3, 'class'].value_counts()[y]
x.index[0]
food['class'].value_counts()
#---2번째 방법
x_train = np.array(food.iloc[:,1:3])
x_train.shape
y = np.array([[6,4]])
y.shape
x_train - y
food['dist'] = np.sqrt(np.sum(np.square(x_train - y),axis=1))
food['rank'] = food['dist'].rank(ascending=True,method='dense').astype(int)
food[food['rank'] <=3]['class']

from collections import Counter
Counter(food[food['rank'] <=3]['class']).most_common(1)[0][0] # 가장큰 값 뽑기 most_common

#---3번째 방법(KNN)
import numpy as np
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
x_train = np.array(food.iloc[:,1:3])
x_train.shape
label = food['class']
label

clf = KNeighborsClassifier(n_neighbors=3)
clf.fit(x_train,label)
clf.predict([[6,4]])[0]
